# %% [markdown]
# # Lab: GPA 🎓
#
# In this lab, you'll explore the GPA dataset and find out about the easiest, hardest, and most popular courses at Illinois!
#
# The dataset you're using in this lab is the same dataset that Professor Wade uses to make the GPA visualizations! :)  Check this out here if you haven't seen it already: [https://waf.cs.illinois.edu/discovery/grade_disparity_between_sections_at_uiuc/](https://waf.cs.illinois.edu/discovery/grade_disparity_between_sections_at_uiuc/)
#
# A few tips to remember:
#
# - Refer to your **lecture notebook** and the **pandas cheat sheet** to help you out with the code!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you're giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We're here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Your Lab Group
#
# Edit the next Python cell to add information about who you're working within your lab section:

# %%
# First, meet your CAs and TA if you haven't already!
# First name is enough, we'll know who they are! :)
ta_name = "Tianyi"
ca1_name = "Jerry"
ca2_name = "Vikram"


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!
#
# QOTD to Ask Your Group: "Not including STAT 107, what is your favorite course this semester?"
partner1_name = "Charlotte"
partner1_netid = "cs112"
partner1_fav_course = "science of pets"

partner2_name = ""
partner2_netid = ""
partner2_fav_course = ""

partner3_name = ""
partner3_netid = ""
partner3_fav_course = ""

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 1: Basic Data Manipulation
#
# ### Puzzle 1.1: Loading the Dataset
#
# For the first part of our lab, we'll be using the GPA dataset, which should be automatically downloaded when you fetch this notebook.
#
# In the following cell, load the pandas library and read the dataset into `df`.  You can find the GPA dataset at:
#
# ```
# https://waf.cs.illinois.edu/discovery/gpa.csv
# ```

# %%
# Import the gpa.csv dataset below
import pandas as pd
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/gpa.csv")
df
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 0      2021    Fall  2021-fa     AAS     100   Intro Asian American Studies
# 1      2021    Fall  2021-fa     AAS     100   Intro Asian American Studies
# 2      2021    Fall  2021-fa     AAS     100   Intro Asian American Studies
# 3      2021    Fall  2021-fa     AAS     100   Intro Asian American Studies
# 4      2021    Fall  2021-fa     AAS     100   Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                            ...
# 61552  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 61553  2010  Summer  2010-su    STAT     440    Statistical Data Management
# 61554  2010  Summer  2010-su     TAM     212          Introductory Dynamics
# 61555  2010  Summer  2010-su     TAM     251   Introductory Solid Mechanics
# 61556  2010  Summer  2010-su     TAM     335   Introductory Fluid Mechanics
#
#       Sched Type  A+   A  A-  ...  C+  C  C-  D+  D  D-  F  W  Students  \
# 0            DIS   2  14   2  ...   0  1   0   0  0   0  0  0        30
# 1            DIS   0  15   0  ...   0  2   0   0  0   0  1  0        27
# 2             OD   7   4   1  ...   2  3   0   0  1   0  1  0        27
# 3            DIS   1  18   0  ...   0  0   0   0  0   0  0  0        26
# 4            DIS   0  16   1  ...   0  2   0   0  0   0  0  0        28
# ...          ...  ..  ..  ..  ...  .. ..  ..  .. ..  .. .. ..       ...
# 61552        LEC   5  10   2  ...   0  1   3   0  0   0  2  1        31
# 61553        LEC   4  12   8  ...   0  0   0   0  0   0  0  0        28
# 61554        LEC   0   1   3  ...   5  1   1   0  2   0  1  0        28
# 61555        LCD   1   2   2  ...   3  3   2   0  0   1  1  0        21
# 61556        LEC   5   8   9  ...   0  4   0   0  1   0  2  0        39
#
#              Primary Instructor
# 0                 Zheng, Reanne
# 1       Atienza, Paul Michael L
# 2                      Wang, Yu
# 3                 Zheng, Reanne
# 4       Atienza, Paul Michael L
# ...                         ...
# 61552        Stepanov, Alexei G
# 61553              Unger, David
# 61554         Morgan, William T
# 61555  Ott-Monsivais, Stephanie
# 61556          Keane, Richard D
#
# [61557 rows x 23 columns]

# %% [markdown]
# ### Puzzle 1.2: Adding Helper Columns
#
# Add a new column called `"Average GPA"`, that computes the average GPA for each course.  You've done this in the PL Homework, but now you're doing it for real! :)
#
# - You shouldn't include students with a `"W"` in either column.
# - The grade point scale can be found at https://registrar.illinois.edu/courses-grades/explanation-of-grades/.

# %%
# add the new column here
df["Average GPA"] = (df["A+"]*4 + df["A"]*4 + df["A-"]*3.67 + df["B+"]*3.33 + df["B"]*3 + df["B-"]*2.67 + df["C+"]*2.33 + df["C"]*2 + df["C-"]*1.67 + df["D+"]*1.33 + df["D"]*1 + df["D-"]*0.67)/df.Students
df
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 0      2021    Fall  2021-fa     AAS     100   Intro Asian American Studies
# 1      2021    Fall  2021-fa     AAS     100   Intro Asian American Studies
# 2      2021    Fall  2021-fa     AAS     100   Intro Asian American Studies
# 3      2021    Fall  2021-fa     AAS     100   Intro Asian American Studies
# 4      2021    Fall  2021-fa     AAS     100   Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                            ...
# 61552  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 61553  2010  Summer  2010-su    STAT     440    Statistical Data Management
# 61554  2010  Summer  2010-su     TAM     212          Introductory Dynamics
# 61555  2010  Summer  2010-su     TAM     251   Introductory Solid Mechanics
# 61556  2010  Summer  2010-su     TAM     335   Introductory Fluid Mechanics
#
#       Sched Type  A+   A  A-  ...  C  C-  D+  D  D-  F  W  Students  \
# 0            DIS   2  14   2  ...  1   0   0  0   0  0  0        30
# 1            DIS   0  15   0  ...  2   0   0  0   0  1  0        27
# 2             OD   7   4   1  ...  3   0   0  1   0  1  0        27
# 3            DIS   1  18   0  ...  0   0   0  0   0  0  0        26
# 4            DIS   0  16   1  ...  2   0   0  0   0  0  0        28
# ...          ...  ..  ..  ..  ... ..  ..  .. ..  .. .. ..       ...
# 61552        LEC   5  10   2  ...  1   3   0  0   0  2  1        31
# 61553        LEC   4  12   8  ...  0   0   0  0   0  0  0        28
# 61554        LEC   0   1   3  ...  1   1   0  2   0  1  0        28
# 61555        LCD   1   2   2  ...  3   2   0  0   1  1  0        21
# 61556        LEC   5   8   9  ...  4   0   0  1   0  2  0        39
#
#              Primary Instructor  Average GPA
# 0                 Zheng, Reanne     3.544667
# 1       Atienza, Paul Michael L     3.394815
# 2                      Wang, Yu     3.098519
# 3                 Zheng, Reanne     3.743462
# 4       Atienza, Paul Michael L     3.547500
# ...                         ...          ...
# 61552        Stepanov, Alexei G     3.183226
# 61553              Unger, David     3.774643
# 61554         Morgan, William T     2.595714
# 61555  Ott-Monsivais, Stephanie     2.603333
# 61556          Keane, Richard D     3.205641
#
# [61557 rows x 24 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(abs(df[(df["YearTerm"] == "2018-fa") & (df["Subject"] == "STAT") & (df["Number"] == 100)]["Average GPA"].mean() - 3.247) < 0.01), "It appears that your \"Average GPA\" column is incorrect."

## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 2: Finding the Easiest and Hardest Courses
#
# ### Puzzle 2.1: Hardest Courses in the Dataset
#
# Based on the `"Average GPA"` column, find the **30 hardest courses** at Illinois, i.e., the 30 courses with the lowest "Average GPA". Store the results in `df_hard`.

# %%
df_hard = df.nsmallest(30, "Average GPA")
df_hard
# Out:
#        Year    Term YearTerm Subject  Number                    Course Title  \
# 16713  2018    Fall  2018-fa     LER     120     Contemporary Labor Problems
# 708    2021    Fall  2021-fa    CLCV     100  Vocab Building-GRK & LAT Roots
# 29185  2016  Spring  2016-sp     LER     100   Introduction to Labor Studies
# 36998  2014    Fall  2014-fa     LER     120     Contemporary Labor Problems
# 1810   2021    Fall  2021-fa     LER     100   Introduction to Labor Studies
# 39266  2014  Spring  2014-sp     LER     120     Contemporary Labor Problems
# 42063  2013    Fall  2013-fa    MATH       2            Introductory Algebra
# 39341  2014  Spring  2014-sp    MATH     220                        Calculus
# 13985  2019  Spring  2019-sp     LER     100   Introduction to Labor Studies
# 26913  2016    Fall  2016-fa     LER     120     Contemporary Labor Problems
# 27181  2016    Fall  2016-fa     MCB     245      Human Anat & Physiol Lab I
# 37045  2014    Fall  2014-fa     LLS     296   Bilingual US Latina/o Culture
# 37209  2014    Fall  2014-fa     MCB     245      Human Anat & Physiol Lab I
# 24114  2017  Spring  2017-sp     LER     100   Introduction to Labor Studies
# 18064  2018  Spring  2018-sp    CHEM     101          Introductory Chemistry
# 26909  2016    Fall  2016-fa     LER     100   Introduction to Labor Studies
# 26912  2016    Fall  2016-fa     LER     110      Labor and Social Movements
# 52533  2011  Spring  2011-sp    MATH     115        Preparation for Calculus
# 27172  2016    Fall  2016-fa     MCB     245      Human Anat & Physiol Lab I
# 52469  2011  Spring  2011-sp     LER     100   Introduction to Labor Studies
# 38861  2014  Spring  2014-sp    ENGL     274           Contemporary Classics
# 31976  2015    Fall  2015-fa    MATH     181            A Mathematical World
# 16923  2018    Fall  2018-fa     MCB     245      Human Anat & Physiol Lab I
# 27177  2016    Fall  2016-fa     MCB     245      Human Anat & Physiol Lab I
# 4884   2021  Summer  2021-su    CHEM     102             General Chemistry I
# 50881  2011    Fall  2011-fa     TAM     251    Introductory Solid Mechanics
# 56089  2011  Summer  2011-su     TAM     251    Introductory Solid Mechanics
# 36794  2014    Fall  2014-fa      IE     300                Analysis of Data
# 44371  2013  Spring  2013-sp    MATH     115        Preparation for Calculus
# 14822  2019  Summer  2019-su    CHEM     102             General Chemistry I
#
#       Sched Type  A+  A  A-  ...   C  C-  D+   D  D-   F  W  Students  \
# 16713        ONL   0  0   1  ...   1   2   1   1   0  15  0        28
# 708          ONL   2  0   3  ...   1   0   1   2   3  20  0        40
# 29185        ONL   0  1   0  ...   4   1   1   1   1  10  0        24
# 36998        ONL   0  4   0  ...   4   1   0   1   0  15  1        30
# 1810         ONL   0  1   0  ...   3   0   2   0   1  11  0        26
# 39266        ONL   0  1   3  ...   3   0   0   0   2  11  0        25
# 42063        LCD   0  0   0  ...  10   5   3   3   2   5  3        31
# 39341        LBD   0  3   0  ...   5   0   2   1   0  11  1        28
# 13985        ONL   0  2   1  ...   0   0   0   2   1   9  0        21
# 26913        NaN   0  2   2  ...   0   1   2   1   2   8  2        22
# 27181        NaN   0  0   0  ...   3   4   1   2   0   6  1        23
# 37045        LCD   3  1   0  ...   1   1   1   0   2  11  1        27
# 37209        LAB   0  0   1  ...   1   3   5   1   1   5  0        25
# 24114        NaN   0  2   1  ...   3   2   0   1   0   9  0        23
# 18064        NaN   1  5   8  ...  10   9  11  23  10  26  7       132
# 26909        NaN   0  2   1  ...   3   2   0   1   1  10  0        27
# 26912        NaN   0  4   2  ...   2   1   0   1   4   8  0        25
# 52533        LCD   1  4   2  ...   5   0   9  11   2  18  0        71
# 27172        NaN   0  0   1  ...   1   3   3   4   1   4  2        25
# 52469        ONL   2  1   0  ...   1   2   0   0   1   9  2        22
# 38861        LCD   0  1   3  ...   1   2   1   0   0   8  1        21
# 31976        LCD   1  3   0  ...   3   1   1   1   1   8  0        23
# 16923        LAB   0  0   1  ...   4   1   0   1   1   7  0        23
# 27177        NaN   0  0   1  ...   3   1   1   1   3   6  0        26
# 4884         ONL   2  3   4  ...  10   4   7  10  13  13  1        85
# 50881        LEC   1  0   4  ...  23   3   6  23   9  11  0       102
# 56089        LEC   1  0   4  ...  23   3   6  23   9  11  0       102
# 36794        LEC   4  1   3  ...  13  10   9   8   2  14  4        75
# 44371        LCD   0  3   5  ...   9   6   6   3   6  26  4        96
# 14822        ONL   0  2   2  ...   4   3   3   3   9  10  6        52
#
#           Primary Instructor  Average GPA
# 16713            Taylor, Don     1.142857
# 708    Augoustakis, Antonios     1.208750
# 29185       Hawking, Carol J     1.319583
# 36998      Hershfield, David     1.400000
# 1810           Ashby, Steven     1.410385
# 39266      Cohen, Margaret L     1.427600
# 42063    Aydin-Mullen, Yelda     1.430645
# 39341     Gilbert, Rebekah A     1.476071
# 13985      Cohen, Margaret L     1.491905
# 26913      Hershfield, David     1.515455
# 27181       Swigart, James P     1.522174
# 37045      Romero, Rolando J     1.568519
# 37209       Swigart, James P     1.586800
# 24114          Ashby, Steven     1.594783
# 18064      Decoste, Donald J     1.598864
# 26909     Stewart, Beverly L     1.605185
# 26912          Ashby, Steven     1.614400
# 52533        Carty, Thomas E     1.619296
# 27172       Swigart, James P     1.626800
# 52469        Konopacki, Mike     1.636364
# 38861         Hutner, Gordon     1.651429
# 31976          Loeb, Sarah J     1.651739
# 16923       Swigart, James P     1.652174
# 27177       Swigart, James P     1.654231
# 4884         Marville, Kelly     1.655294
# 50881   Starzewski, Martin O     1.657157
# 56089   Starzewski, Martin O     1.657157
# 36794         Tursun, Umit D     1.662400
# 44371    Lansing, Jennifer L     1.663438
# 14822        Marville, Kelly     1.667115
#
# [30 rows x 24 columns]

# %% [markdown]
# ### Puzzle 2.2: "Level" of Hardest Courses
#
# Find the average `"Number"` of the **30 hardest courses** at Illinois. Store the result as `df_hard_avg`.

# %%
df_hard_avg = df_hard["Number"].mean()
df_hard_avg
# Out:
# 160.83333333333334

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 2.1 and 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell(s), make changes, and RE-RUN your code and then this cell.
import math
assert( math.isclose(df_hard_avg, 160.83333333333334) ), "It appears that your average \"Number\" is incorrect. Please check both Puzzle 2.1 and Puzzle 2.2."
## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.3: ❓ Individual Reflection Question ❓ Are the Hardest Courses Really "Hard"?
#
# After solving Puzzle 2.1 and 2.2, your friend has the following claim:
#
# > *"We know that the undergraduate courses are coded from 001 to 499, where a larger number (in the hundreds place) usually implies more advanced material.  Based on our results in the previous puzzles, the data shows that the junior-level and senior-level courses are clearly not the hardest courses at UIUC."*
#
# Comment on your friend's claim below. Do you think he is correct? Explain why or why not in at least three complete sentences.

# %% [markdown]
# *(✏️ Edit this cell to replace this text wth your answer this puzzle. ✏️)*

# %% [markdown]
# ### Puzzle 2.4: Easiest Courses in 2021
#
# Based on the `"Average GPA"` column, find the **30 easiest courses in 2021** at UIUC. Store the results in `df_easy_2021`.

# %%
df2021 = df[df.Year == 2021]
df_easy_2021 = df2021.nlargest(30, "Average GPA")
df_easy_2021
# Out:
#       Year    Term YearTerm Subject  Number                    Course Title  \
# 4954  2021  Summer  2021-su      IS     537  Theory & Prct of Data Cleaning
# 1200  2021    Fall  2021-fa    EPOL     500              Proseminar in EPOL
# 2157  2021    Fall  2021-fa    MUSC     480                   Wind Symphony
# 1992  2021    Fall  2021-fa     MBA     564   Applying Data Analytics Mrktg
# 3477  2021  Spring  2021-sp    DANC     100     Intro to Contemporary Dance
# 4796  2021  Spring  2021-sp      TE     360  Lect in Engrg Entrepreneurship
# 3724  2021  Spring  2021-sp     EPS     533    Global Youth and Citizenship
# 4020  2021  Spring  2021-sp      IS     507                Data, Stat, Info
# 1203  2021    Fall  2021-fa    EPOL     524      Education and Human Rights
# 787   2021    Fall  2021-fa     CMN     432            Gender Communication
# 402   2021    Fall  2021-fa    BADM     367    Mgmt of Innov and Technology
# 4018  2021  Spring  2021-sp      IS     505             Info Org and Access
# 544   2021    Fall  2021-fa     BUS     301              Business in Action
# 2866  2021  Spring  2021-sp     ADV     350    Writing for Public Relations
# 1547  2021    Fall  2021-fa      IS     407    Introduction to Data Science
# 1318  2021    Fall  2021-fa    FSHN     422    Intro Personalized Nutrition
# 531   2021    Fall  2021-fa     BUS     201               Business Dynamics
# 423   2021    Fall  2021-fa    BADM     453           Business Intelligence
# 3160  2021  Spring  2021-sp     BUS     201               Business Dynamics
# 3076  2021  Spring  2021-sp    BADM     375           Operations Management
# 528   2021    Fall  2021-fa     BUS     101  Prof Responsibility & Business
# 2711  2021  Spring  2021-sp     ABE     425       Engrg Measurement Systems
# 529   2021    Fall  2021-fa     BUS     101  Prof Responsibility & Business
# 1733  2021    Fall  2021-fa     LAS     101    Design First Year Experience
# 543   2021    Fall  2021-fa     BUS     301              Business in Action
# 890   2021    Fall  2021-fa      CS     598    Foundations of Data Curation
# 3296  2021  Spring  2021-sp      CI     473           Disciplinary Literacy
# 4955  2021  Summer  2021-su      IS     565      Cataloging for School Libs
# 1584  2021    Fall  2021-fa      IS     582          Academic Librarianship
# 3185  2021  Spring  2021-sp     CEE     462             Steel Structures II
#
#      Sched Type   A+    A  A-  ...  C  C-  D+  D  D-  F  W  Students  \
# 4954        ONL  407    9   0  ...  0   0   0  0   0  0  0       419
# 1200        ONL    0   80   0  ...  0   0   0  0   0  0  0        81
# 2157         PR    0   51   0  ...  0   0   0  0   0  0  0        52
# 1992        ONL    0  680   0  ...  0   0   0  0   0  2  1       683
# 3477        ONL   39   10   0  ...  0   0   0  0   0  0  0        50
# 4796        OLC   47    0   0  ...  0   0   0  0   0  0  0        48
# 3724        ONL    4   42   0  ...  0   0   0  0   0  0  0        47
# 4020        ONL   38    5   0  ...  0   0   0  0   0  0  0        44
# 1203        ONL   29   28   0  ...  0   0   0  0   0  0  0        58
# 787         LCD   33    2   0  ...  0   0   0  0   0  0  0        36
# 402         LCD    0   62   2  ...  0   0   0  0   0  0  0        65
# 4018        ONL   27    4   0  ...  0   0   0  0   0  0  0        32
# 544         LCD    0   45   1  ...  0   0   0  0   0  0  0        47
# 2866        ONL   21    8   0  ...  0   0   0  0   0  0  0        30
# 1547        ONL   53    4   0  ...  0   0   0  0   0  0  0        59
# 1318        ONL    8   20   0  ...  0   0   0  0   0  0  0        29
# 531         LCD    0   52   2  ...  0   0   0  0   0  0  0        55
# 423         LCD   10   42   1  ...  0   0   0  0   0  0  0        54
# 3160        ONL    3   47   2  ...  0   0   0  0   0  0  0        53
# 3076        ONL   32    6   0  ...  0   0   0  0   0  0  0        39
# 528         LCD    0   25   0  ...  0   0   0  0   0  0  0        26
# 2711        OLC   11   26   0  ...  0   0   0  0   0  0  0        38
# 529         LCD    0   24   0  ...  0   0   0  0   0  0  0        25
# 1733        DIS   18    6   0  ...  0   0   0  0   0  0  0        25
# 543         LCD    0   47   1  ...  0   0   0  0   0  0  0        49
# 890         ONL  268   19   2  ...  0   0   0  0   0  1  0       295
# 3296        OLC    0  106   1  ...  0   0   0  0   0  0  0       109
# 4955        ONL   23   12   0  ...  0   0   0  0   0  0  0        36
# 1584        ONL   12   11   0  ...  0   0   0  0   0  0  0        24
# 3185        ONL   31   23   3  ...  0   0   0  0   0  0  0        58
#
#              Primary Instructor  Average GPA
# 4954                        NaN     3.995203
# 1200              Lee, Sharon S     3.987654
# 2157          Peterson, Stephen     3.987115
# 1992              Yun, Joseph T     3.986823
# 3477          Sapozhnikov, Anna     3.986600
# 4796    Harbourt, Christopher M     3.986042
# 3724             Herrera, Linda     3.985745
# 4020        Besser, Stephanie A     3.984773
# 1203         Herman, Thaddeus B     3.982759
# 787                 Huff, Billy     3.981389
# 402   Corredor Waldro, Sandra T     3.979538
# 4018              Choi, Inkyung     3.979062
# 544             Keating, Kari H     3.978723
# 2866          Peacock, Marisa C     3.977667
# 1547        Besser, Stephanie A     3.977288
# 1318            Pan, Yuan-Xiang     3.976897
# 531           Sanchez, Carmen J     3.975818
# 423               Ivanov, Anton     3.975370
# 3160         Luckman, Elizabeth     3.974906
# 3076             Liang, Hongyan     3.974359
# 528              Barbeau, Aimee     3.974231
# 2711              Grift, Tony E     3.973684
# 529              Barbeau, Aimee     3.973200
# 1733            Khneisser, Mona     3.973200
# 543             Noonan, James R     3.972857
# 890             Renear, Allen H     3.972847
# 3296           Filkins, Scott R     3.972569
# 4955           Shasteen, Ruth H     3.972222
# 1584            Wong, Melissa A     3.972083
# 3185        Fahnestock, Larry A     3.971379
#
# [30 rows x 24 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 2.4 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, RE-RUN your code, and then RE-RUN this cell.
import math
assert( len(df_easy_2021) == 30 ), "You should only have the 30 easiest courses in 2021."
assert( math.isclose(df_easy_2021["Average GPA"].mean(), 3.97873347181759) ), "Are you sure you have the 30 easiest courses in 2021?"
## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 3: Finding Data by Subject
#
# ### Puzzle 3.1: Total Number of Grades by Subject
#
# Find the total number of each grade ("A+"s, "A"s, "A-"s, etc.) given by different subjects. Store the results in `df_group`.

# %%
df_group = df.groupby("Subject").agg("sum").reset_index()
df_group
# Out:
#     Subject     Year  Number    A+      A     A-     B+      B    B-    C+  \
# 0       AAS   437402   27754   970   2524    944    600    615   275   157
# 1       ABE   302329   50447   373   2885    851    772    972   256   143
# 2      ACCY  5125712  945991  9939  29009  18849  17295  16293  6818  3380
# 3       ACE  2023605  279051  5390  16378   5858   4878   8015  2943  1896
# 4      ACES   340627   19655  1234   2003    311    159    307    80    81
# ..      ...      ...     ...   ...    ...    ...    ...    ...   ...   ...
# 163      UP   640866  114557  1245   4059   2247   1348   1449   538   280
# 164      VB     8040    2489     0    212      6      6    120     1     0
# 165     VCM    78489   25394   311   1374     29     49   1040    20    19
# 166      VM   219733   66343     0   2221      8      0   6785     1     0
# 167    YDSH    28196    3880    56    114     87     37     44    16    10
#
#         C    C-   D+    D   D-    F    W  Students  Average GPA    All GPA
# 0     170    64   35   40   21  106   24      6521   760.952413   22931.04
# 1     188    50   17   46    8   56   17      6617   524.843647   23192.11
# 2    2669  1325  375  782  233  694  297    107661  8624.354931  366506.25
# 3    2724   889  434  769  253  822  120     51249  3313.398977  169583.45
# 4      94    34   23   31   15   88    8      4460   619.782761   16258.59
# ..    ...   ...  ...  ...  ...  ...  ...       ...          ...        ...
# 163   318   141   46   89   58  201   41     12019  1109.908968   41447.70
# 164    40     0    0    2    0    0    0       387    13.974534    1334.67
# 165   337     1    1   41    0    2    0      3224   135.763822   10945.27
# 166  4047     0    0  423    0   13   10     13498   308.142917   37788.03
# 167     7     5    1    2    2   10    3       391    48.795454    1347.54
#
# [168 rows x 20 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 3.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, RE-RUN your code, and then RE-RUN this cell.
assert( len(df_group) == 168 ), "Are you sure you grouped by subjects?"
assert( df_group[ df_group["Subject"] == "CS" ]["A"].values[0] == 60835 ), "Are you sure you counted the right number of each subject?"
## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.2: Average GPA by Subject
#
# In `df_group`, add a new column called `"Overall Average GPA"` that computes the overall GPA of each subject at UIUC.

# %%
df["All GPA"] = df["Average GPA"]*df.Students
df_group["Overall Average GPA"] = df_group["All GPA"] / df_group.Students
df_group
# Out:
#     Subject     Year  Number    A+      A     A-     B+      B    B-    C+  \
# 0       AAS   437402   27754   970   2524    944    600    615   275   157
# 1       ABE   302329   50447   373   2885    851    772    972   256   143
# 2      ACCY  5125712  945991  9939  29009  18849  17295  16293  6818  3380
# 3       ACE  2023605  279051  5390  16378   5858   4878   8015  2943  1896
# 4      ACES   340627   19655  1234   2003    311    159    307    80    81
# ..      ...      ...     ...   ...    ...    ...    ...    ...   ...   ...
# 163      UP   640866  114557  1245   4059   2247   1348   1449   538   280
# 164      VB     8040    2489     0    212      6      6    120     1     0
# 165     VCM    78489   25394   311   1374     29     49   1040    20    19
# 166      VM   219733   66343     0   2221      8      0   6785     1     0
# 167    YDSH    28196    3880    56    114     87     37     44    16    10
#
#      ...    C-   D+    D   D-    F    W  Students  Average GPA    All GPA  \
# 0    ...    64   35   40   21  106   24      6521   760.952413   22931.04
# 1    ...    50   17   46    8   56   17      6617   524.843647   23192.11
# 2    ...  1325  375  782  233  694  297    107661  8624.354931  366506.25
# 3    ...   889  434  769  253  822  120     51249  3313.398977  169583.45
# 4    ...    34   23   31   15   88    8      4460   619.782761   16258.59
# ..   ...   ...  ...  ...  ...  ...  ...       ...          ...        ...
# 163  ...   141   46   89   58  201   41     12019  1109.908968   41447.70
# 164  ...     0    0    2    0    0    0       387    13.974534    1334.67
# 165  ...     1    1   41    0    2    0      3224   135.763822   10945.27
# 166  ...     0    0  423    0   13   10     13498   308.142917   37788.03
# 167  ...     5    1    2    2   10    3       391    48.795454    1347.54
#
#      Overall Average GPA
# 0               3.516491
# 1               3.504928
# 2               3.404262
# 3               3.309010
# 4               3.645424
# ..                   ...
# 163             3.448515
# 164             3.448760
# 165             3.394935
# 166             2.799528
# 167             3.446394
#
# [168 rows x 21 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == TEST CASES for Puzzle 3.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, RE-RUN your code, and then RE-RUN this cell.
import math
assert( math.isclose(df_group[df_group["Subject"] == "CS"]["Overall Average GPA"].values[0], 3.328369588478247) ), "Your overall average GPA doesn't appear to be correct."
## == SUCCESS MESSAGE ==
# You'll only see this message (With the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.3: Visualizing the Grades of Subject Equal to `"STAT"`
#
# Create a bar chart of the grades (`"A+"` to `"F"`) for the subject `"STAT"`.

# %%
df_STAT = df_group[df_group.Subject == "STAT"]
df_STAT
df_STAT_Grade = df_STAT.loc[:,'A+':'F']
df_STAT_Grade.plot.bar()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Puzzle 3.4: ❓ Individual Reflection Question ❓
#
# Bar Chart vs. Histogram
#
# Why should we use a bar chart in Puzzle 3.3? Would it make sense to use a density histogram as well? Answer this question with at least 3 complete sentences!

# %% [markdown]
# We can discover the difference of the number of students receving different scores easily by the bar chart. It would also make sense if we use a density histogram. Because it can represent the percentage of students receiving different grades.

# %% [markdown]
# ### Puzzle 3.5: Find Your Major
#
# Finally, find your major in the dataset and check out how hard it is!
#
# Feel free to look around and explore! Part of being a data scientist is being creative and using Python to answer questions that you have.  Write your code below to determine how hard your major is and write comments in Puzzle 3.6 to explain what your code does. For example, what are the hardest classes in your major that have had at least 50 students?

# %%
# Feel free to explore. Credit will be given as long as you try some new code (i.e., not directly copied from any puzzles).

# importing packages
import matplotlib.pyplot as plt
  
# plot a Stacked Bar Chart using matplotlib

df_Compare_STAT = df[df.Subject == "STAT"]
df_STAT_Each_Year = df_Compare_STAT.groupby("Year").agg("mean").reset_index()
df_STAT_Each_Year = df_STAT_Each_Year.drop("Number",axis = 1)
df_STAT_Each_Year["A+%"] = df_STAT_Each_Year["A+"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["A%"] = df_STAT_Each_Year["A"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["B+%"] = df_STAT_Each_Year["B+"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["B%"] = df_STAT_Each_Year["B"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["B-%"] = df_STAT_Each_Year["B-"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["C+%"] = df_STAT_Each_Year["C+"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["C%"] = df_STAT_Each_Year["C"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["C-%"] = df_STAT_Each_Year["C-"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["D+%"] = df_STAT_Each_Year["D+"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["D%"] = df_STAT_Each_Year["D"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["D-%"] = df_STAT_Each_Year["D-"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["F%"] = df_STAT_Each_Year["F"]/df_STAT_Each_Year.Students
df_STAT_Each_Year["Years"] = df_STAT_Each_Year["Year"]
Grade = df_STAT_Each_Year.loc[:,'A+%':'Years']
Grade.plot(
    x = 'Years',
    kind = 'barh',
    stacked = True,
    title = 'Compare STAT GPA between Years',
    mark_right = True)
# Out:
# <AxesSubplot: title={'center': 'Compare STAT GPA between Years'}, ylabel='Years'>

# %% [markdown]
# ### Puzzle 3.6: ❓ Individual Reflection Question ❓
#
# Explain what you did in Puzzle 3.5 here, as well as what you found!  This is your chance to interpret your results and teach us something that you found interesting :) Write at least 3 complete sentences.

# %% [markdown]
# *(✏️ Edit this cell to replace this text wth your answer this puzzle. ✏️)*
# I compared stats gpa between years. Each stacked graph represent the percentage of each grade. From the stacked graph i see that students receive more A in 2020.In 2021 the most students receive A+ than other years.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Finale!
#
# You're almost done! All you need to do is to commit your lab to GitHub:
#
# 1. Make certain to save your work. To do this, go to **File => Save All**
#
# 2. After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
