# %%
import pandas as pd

# %%
df = pd.read_csv("Google-Playstore.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/scarlett_hjq/Desktop/stat107/jiaqi22/project2/Google-Playstore_analysis.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/scarlett_hjq/Desktop/stat107/jiaqi22/project2/Google-Playstore_analysis.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("Google-Playstore.csv")
#       <a href='vscode-notebook-cell:/Users/scarlett_hjq/Desktop/stat107/jiaqi22/project2/Google-Playstore_analysis.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
# ...

# %% [markdown]
# popularity

# %%
df_most_popular = df.nlargest(10,"Maximum Installs")
df_most_popular.sort_values("Maximum Installs", ascending=False)
# Out:
#                                  App Name  \
# 2155096              Google Play services
# 881403                            YouTube
# 1773294                            Google
# 1733042  Google Maps - Navigate & Explore
# 1060335             Google Text-to-Speech
# 944254       Google Chrome: Fast & Secure
# 2099458                             Gmail
# 2011395       Android Accessibility Suite
# 893676                       Google Drive
# 2222701                          Facebook
#
#                                           App Id                 Category  \
# 2155096                   com.google.android.gms                    Tools
# 881403                com.google.android.youtube  Video Players & Editors
# 1773294  com.google.android.googlequicksearchbox                    Tools
# 1733042             com.google.android.apps.maps           Travel & Local
# 1060335                   com.google.android.tts                    Tools
# ...

# %%
df['Percentile Rank'] = df["Maximum Installs"].rank(pct = True)

# %%
df["Maximum Installs"].mean()
# Out:
# 320201.713137456

# %%
df["Maximum Installs"].median()
# Out:
# 695.0

# %%
df["Maximum Installs"].plot.box()
# Out:
# <AxesSubplot: >

# %%
df_type = df.groupby(["Category"]).count()
df_type = df_type.sort_values("App Name")
df_type.sort_values("App Name", ascending = False)
# Out:
#                          App Name  App Id  Rating  Rating Count  Installs  \
# Category
# Education                  241090  241090  239786        239786    241090
# Music & Audio              154906  154906  154589        154589    154906
# Tools                      143988  143988  141972        141972    143985
# Business                   143771  143771  142151        142151    143771
# Entertainment              138276  138276  137578        137578    138275
# Lifestyle                  118331  118331  117764        117764    118331
# Books & Reference          116728  116728  116493        116493    116728
# Personalization             89210   89210   89012         89012     89209
# Health & Fitness            83510   83510   82598         82598     83509
# Productivity                79698   79698   78244         78244     79698
# Shopping                    75256   75256   74753         74753     75253
# ...

# %% [markdown]
# Price

# %%
len(df[df.Free == True])
# Out:
# 2267876

# %%
len(df[df.Free == False])
# Out:
# 45068

# %%
len(df[(df.Free == True) & (df["In App Purchases"] == False) & (df["Ad Supported"] == False)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/scarlett_hjq/Desktop/stat107/jiaqi22/proj_appstore/Untitled-1.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/scarlett_hjq/Desktop/stat107/jiaqi22/proj_appstore/Untitled-1.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> len(df[(df.Free == True) & (df["In App Purchases"] == False) & (df["Ad Supported"] == False)])
#
# NameError: name 'df' is not defined

# %%
len(df[(df.Free == True) & (df["In App Purchases"] == True)])
# Out:
# 192274

# %%
len(df[(df.Free == False) & (df["In App Purchases"] == True)])
# Out:
# 3035

# %%
len(df[(df.Free == False) & (df["In App Purchases"] == False)])
# Out:
# 42033

# %%
df_popular_but_bad = df[(df["Minimum Installs"] > 10000000) & (df["Rating"] < 3)]
